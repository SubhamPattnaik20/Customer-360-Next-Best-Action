# %%
import pandas as pd

df = pd.read_csv('data/raw/olist_customer360_master_dataset.csv')
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('data/raw/olist_customer360_master_dataset.csv')
#       4 print(df.shape)
#       5 df.head()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/raw/olist_customer360_master_dataset.csv')
print(df.shape)
df.head()
# Out:
# (99441, 38)
#                            order_id                       customer_id  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
# 1  e5fa5a7210941f7d56d0208e4e071d35  683c54fc24d40ee9f8a6fc179fd9856c
# 2  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 3  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 4  71303d7e93b399f5bcd537d124c0bcfa  b106b360fe2ef8849fbbd056f777b4d5
#
#                  customer_unique_id         customer_city customer_state  \
# 0  b7d76e111c89f7ebf14761390f0f7d17             boa vista             RR
# 1  4854e9b3feff728c13ee5fc7d1547e92           passo fundo             RS
# 2  009b0127b727ab0ba422f6d9604487c7   sao jose dos campos             SP
# 3  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
# 4  0eb1ee9dba87f5b36b4613a65074337c             sao paulo             SP
#
#    customer_zip_code_prefix order_status order_purchase_timestamp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   customer_unique_id             99441 non-null  str
#  3   customer_city                  99441 non-null  str
#  4   customer_state                 99441 non-null  str
#  5   customer_zip_code_prefix       99441 non-null  int64
#  6   order_status                   99441 non-null  str
#  7   order_purchase_timestamp       99441 non-null  str
#  8   order_approved_at              99281 non-null  str
#  9   order_delivered_carrier_date   97658 non-null  str
#  10  order_delivered_customer_date  96476 non-null  str
#  11  order_estimated_delivery_date  99441 non-null  str
#  12  order_year                     99441 non-null  int64
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# review_comment_title             87891
# review_comment_message           58666
# delivery_time_days                2965
# order_delivered_customer_date     2965
# delivery_delay_days               2965
# product_category                  2191
# order_delivered_carrier_date      1783
# product_length_cm                  791
# product_height_cm                  791
# product_weight_g                   791
# product_width_cm                   791
# seller_city                        775
# seller_id                          775
# seller_state                       775
# total_freight                      775
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['seller_id'].isnull()][['order_id','seller_id','seller_city','product_width_cm']].head()
# Out:
#                             order_id seller_id seller_city  product_width_cm
# 2   809a282bbd5dbcabb6f2f724fca862ec       NaN         NaN               NaN
# 16  1aecadf4362edaca7fa033e882076c8d       NaN         NaN               NaN
# 20  620b0acb9258b51defbc51804c5298d5       NaN         NaN               NaN
# 59  ddaec6fff982b13e7e048b627a11d6da       NaN         NaN               NaN
# 77  a68ce1686d536ca72bd2dadc4b8671e5       NaN         NaN               NaN

# %%
df_clean = df.dropna(subset=['seller_id']).copy()
print(df_clean.shape)
# Out:
# (98666, 38)

# %%
df_clean.to_csv('../data/processed/olist_customer360_clean.csv', index=False)
print("Saved!")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_clean.to_csv('../data/processed/olist_customer360_clean.csv', index=False)
#       2 print("Saved!")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:3976, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3972             float_format=float_format,
#    3973             decimal=decimal,
#    3974         )
#    3975
# -> 3976         return DataFrameRenderer(formatter).to_csv(
#    3977             path_or_buf,
#    3978             lineterminator=lineterminator,
#    3979             sep=sep,
#
# ...

# %%
df_clean.to_csv('../data/processed/olist_customer360_clean.csv', index=False)
print("Saved!")
# Out:
# Saved!

# %%
print(list(df_clean.columns))
# Out:
# ['order_id', 'customer_id', 'customer_unique_id', 'customer_city', 'customer_state', 'customer_zip_code_prefix', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_year', 'order_month', 'order_weekday', 'delivery_time_days', 'estimated_delivery_days', 'delivery_delay_days', 'is_late_delivery', 'product_id', 'product_category', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'seller_id', 'seller_city', 'seller_state', 'total_items', 'total_price', 'total_freight', 'avg_item_price', 'total_payment_value', 'payment_type_main', 'payment_installments_max', 'review_score', 'review_comment_title', 'review_comment_message']

# %%
for col in df_clean.columns:
    print(col)
# Out:
# order_id
# customer_id
# customer_unique_id
# customer_city
# customer_state
# customer_zip_code_prefix
# order_status
# order_purchase_timestamp
# order_approved_at
# order_delivered_carrier_date
# order_delivered_customer_date
# order_estimated_delivery_date
# order_year
# order_month
# order_weekday
# delivery_time_days
# estimated_delivery_days
# delivery_delay_days
# is_late_delivery
# product_id
# product_category
# product_weight_g
# product_length_cm
# product_height_cm
# product_width_cm
# seller_id
# seller_city
# seller_state
# total_items
# total_price
# total_freight
# avg_item_price
# total_payment_value
# payment_type_main
# payment_installments_max
# review_score
# review_comment_title
# review_comment_message

# %%
with open('../data/processed/column_list.txt', 'w') as f:
    for col in df_clean.columns:
        f.write(col + '\n')
print("Saved column list")
# Out:
# Saved column list

# %%
print(df_clean['delivery_time_days'].dtype)
print(df_clean['delivery_time_days'].head(10))
# Out:
# float64
# 0      NaN
# 1      NaN
# 3     54.0
# 4      NaN
# 5     23.0
# 6     24.0
# 7     35.0
# 8     30.0
# 9     27.0
# 10    10.0
# Name: delivery_time_days, dtype: float64

# %%
from sqlalchemy import create_engine

# Replace 'yourpassword' with your actual MySQL root password
engine = create_engine("mysql+pymysql://root:yourpassword@localhost/customer360")

df_clean.to_sql('customers360', con=engine, if_exists='replace', index=False)
print("Loaded into MySQL!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
# ...

# %%
engine = create_engine("mysql+pymysql://root:Subham2026sql@localhost/customer360")

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:Subham@2026@localhost/customer360")

df_clean.to_sql('customers360', con=engine, if_exists='replace', index=False)
print("Loaded into MySQL!")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pymysql\connections.py:682, in Connection.connect(self, sock)
#     681 try:
# --> 682     sock = socket.create_connection(
#     683         (self.host, self.port), self.connect_timeout, **kwargs
#     684     )
#     685     break
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\socket.py:850, in create_connection(address, timeout, source_address, all_errors)
#     849 exceptions = []
# --> 850 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     851     af, socktype, proto, canonname, sa = res
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\socket.py:989, in getaddrinfo(host, port, family, type, proto, flags)
#     988 addrlist = []
# --> 989 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
engine = create_engine("mysql+pymysql://root:Subham%402026@localhost/customer360")

# %%
engine = create_engine("mysql+pymysql://root:Subham%402026@127.0.0.1:3306/customer360")

# %%
df_clean.to_sql('customers360', con=engine, if_exists='replace', index=False)
print("Loaded into MySQL!")
# Out:
# Loaded into MySQL!

# %%
import pandas as pd

df_rfm = pd.read_csv(r"C:\Users\pattn\OneDrive\Desktop\Customer-360-Next-Best-Action\Data\Raw\olist_customer_level_rfm.csv")
df_rfm.to_sql('customer_rfm', con=engine, if_exists='replace', index=False)
print("RFM table loaded into MySQL!")
# Out:
# RFM table loaded into MySQL!

# %%
df_clv = pd.read_csv(r"C:\Users\pattn\OneDrive\Desktop\Customer-360-Next-Best-Action\Data\Raw\olist_customer_clv.csv")
df_clv.to_sql('customer_clv', con=engine, if_exists='replace', index=False)
print("CLV table loaded into MySQL!")
# Out:
# CLV table loaded into MySQL!

# %%
df_nba = pd.read_csv(r"C:\Users\pattn\OneDrive\Desktop\Customer-360-Next-Best-Action\Data\Raw\olist_next_best_action.csv")
df_nba.to_sql('next_best_action', con=engine, if_exists='replace', index=False)
print("NBA table loaded into MySQL!")
# Out:
# NBA table loaded into MySQL!
